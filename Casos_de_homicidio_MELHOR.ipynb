# %% [markdown]
# # Homens são as maiores vitimas de homicidio a domicilio do Brasil
# ###### Dados retirados da ONU e de pesquisas renomadas mostram que homens sofrem mais agressões do que mulheres em domicilio e nas ruas.

# %% [markdown]
# ## Motivação da pesquisa
# A motivação para este feito foi o o fato da má comunicação entre as pessoas e jornalistas, estes que vivem colocando informações de pesquisas má comentadas, por isso eu como estudante na área de Ciências da Computação **MATHEUS MMS** apoiador do MBL(Movimento Brasil Livre) estou trazendo este documento para abrir o questionamento sobre o feminicidio.

# %% [markdown]
# ## Agressão as mulheres
# Está claro que na sociedade de hoje nós temos muitas pessoas que são a favor ao feminismo e tais essas acham que temos que impôr direitos iguais. Existem jornais e revistas que usam destas pessoas apoiadores(as) deste movimento para se aproveitarem, um exemplo disso é uma revista muito conhecida no nosso páis, a **EXAME**(exame.com) que a algum tempo fez uma publicação com o título: *Mulheres são minoria nos homicídios, mas estão mais vulneráveis em casa*
# <br>
# <br>
# Eu vendo os dados que estava no artigo percebi que os homens são as maiores vitimas de homicidio do brasil, para ver se este artigo teria mesmo informações corretas acabei pesquisando e vi que sim, as suas porcentagens estavam certas.

# %% [markdown]
# ## Revista EXAME
#
# O O artigo está neste link: [Artigo da revista](https://exame.com/brasil/mulheres-sao-minoria-nos-homicidios-mas-estao-mais-vulneraveis-em-casa/). Nele eu peguei as seguintes informações:<br>
# https://prnt.sc/vpv7pq<br>
# https://prnt.sc/vpv879
# <br>
# <br>
# No primeiro *print* podemos ver o título da máteria e no segundo algumas informações interessante que serão comparadas nas nossas analizes com outras informações que tiraremos da **ONU**, **IPEA** e do **DATASUS**. Todas as refêrencias bibliograficas serão escritas no final do documento, e tudo que sair dessas fontes eu irei informar.
#
# ### Analize dos dados
# **Obs: As porcentagens e os dados estavam totalmente corretos aos que temos disponivel no site do Atlas da violencia**<br>
# Com o segundo *print* nós conseguimos retirar os seguintes dados:
# <br>
# Sendo:
# <br>
# ```
# T: Total de homicidios
#
# TH: Total de homicidios masculinos
# THD: Total de homicidios masculinos a domicilio
#
# TM: Total de homicidios femininos
# TMD: Total de homicidios femininos a domicilio
# ```
# Temos:
# ```
# # T = 619000
#
# # ---------------------------------------------------------------
# # TH = T * 91.8%
# # THD = TH * 15.9%
# #----------------------------------------------------------------
# # TM = T * 8%
# # TMD = TM * 39.2%
# #----------------------------------------------------------------
# # TH = 568242
# # THD = 90350.478
# #----------------------------------------------------------------
# # TM = 49520
# # TMD = 19411.84
# # ---------------------------------------------------------------
# ```
# Nesta analize feita por mim podemos ver que o homem é de fato a maior vitima de homicidio sendo fora ou dentro de casa.<br>
# **Para melhor entendimento e confiabilidade fiz pesquisas e montei uma analize tanto quanto boa e confiavel**

# %% [markdown]
# ## Analizando dados de pesquisas
# A primeira analise foi usando os dados do **Atlas da violencia**, pegamos os arquivos `.csv` que se referiam a quantidade de homicidios ocorridos em todas as Unidades Federativas desde 1979 a 2017 e também usamos os dados de outro arquivo retirado do próprio **Atlas da violencia** que nos informa os homicidios totais no Brasil todo desde 1979 a 2017.
#
# ## Analise de todos os homicidios no Brasil entre 2007 a 2017

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

dados_brasil = pd.read_csv("/content/homicidios_brasil.csv",sep=';')
dados_exame_completo = dados_brasil[dados_brasil.período >= 2007]
plt.plot(dados_exame_completo.período,dados_exame_completo.valor)
plt.xlabel("Ano")
plt.ylabel("Total de homicidios")
plt.grid(True)
plt.title("Total de homicidos no brasil entre 2007 a 2017")
plt.show()

plt.plot(dados_exame_completo.período,dados_exame_completo.valor,'k--', label="Total")
plt.plot(dados_exame_completo.período,dados_exame_completo.valor/100*91.8, label="Homens")
plt.plot(dados_exame_completo.período,dados_exame_completo.valor/100*8, label="Mulheres")
plt.xlabel("Ano")
plt.ylabel("Total de homicidios")
plt.grid(True)
plt.legend()
plt.title("Total de homicidos no brasil dividindo homens e mulheres 2007 a 2017")
plt.show()

plt.plot(dados_exame_completo.período,(((dados_exame_completo.valor/100)*91.8)/100)*15.9, label="Homens")
plt.plot(dados_exame_completo.período,(((dados_exame_completo.valor/100)*8)/100)*39.2, label="Mulheres")
plt.xlabel("Ano")
plt.ylabel("Total de homicidios")
plt.grid(True)
plt.legend()
plt.title("Total de vitimas de homicidos no brasil dividindo homens e mulheres de 2007 a 2017 a domicilio")
plt.show()

# %% [markdown]
# Como acabamos de ver quem é mais vitima de homicidio no brasil sendo dentro ou fora de casa são os homens, então porque o feminicidio existe?
# <br>
# É esse questionamento que eu me faço quando olho para esses dados.
# <br>
# Dados usados para criação do gráfico se encontra para download [aqui](https://www.ipea.gov.br/atlasviolencia/filtros-series).

# %% [markdown]
# ## Quem mais é vitima de homicidio por violencia domestica?
# Sim estão eles novamente, os homens. Fazendo agora uma pesquisa simples usando o TABNET.DATASUS para provar de uma vez por todas que é o homem o mais prejudicado, conseguimos os tais dados na nossa tela efetuando a consulta:<br>
#
# Causas externas em ambiente domestico:<br>
#
# 2010: https://prnt.sc/vq1v04<br>
# 2017: https://prnt.sc/vq1wgt
#
# Agressões domesticas:<br>
#
# 2010: https://prnt.sc/vq34hp<br>
# 2018: https://prnt.sc/vq32sh<br>
#
# [Tabela on-line para conferir](http://tabnet.datasus.gov.br/cgi/tabcgi.exe?sim/cnv/ext10uf.def)<br><br>
# <br>
# <br>

# %% [markdown]
# # Mais explicações para os leigos
# ## Explicando melhor os dados
# Para aqueles que não conseguiram entender o que foi dito mais em cima explicarei em detalhes o que eu quero passar, eu estou tentando passar o pensamento de que nós como seres humanos devemos repensar o motivo das feministas dizerem ser as mulheres as mais vitimizadas quando o assunto é homicidio a domicilio pelo sexo oposto, sendo que é bem ao contrário quando vêmos os dados mais a fundo

# %% [markdown]
# # Resumo
#
# Os homens são as maiores vitimas de homicidio no Brasil, quando o caso é violencia domestica e fora de casa, não tem como não negar a morte de mulheres, mas também não podemos esquecer que temos mais de **3x** a quantidade de homens mortos a domicilio comparado as mulheres...<br><br>
# E agora vem a pergunta do seculo, porque as feministas batem tanto o martelo em cima deste argumento, sendo que os homens são os que mais sofrem?<br><br>
# Temos que acabar com as causas de homicidios em ***GERAL*** e não fazer um movimento que diz ser "igualitario" que vive dizendo oque é certo ou não e afirma dados apenas sobre o sexo feminino...
# <br><br>
# *Obrigado pela compreensão me despeço por aqui.*<br><br>
# *Author: Matheus MMS*<br>
# *Programador: Matheus MMS*
